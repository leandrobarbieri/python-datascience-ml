# %% [markdown]
# <a href="https://colab.research.google.com/github/leandrobarbieri/python-datascience-ml/blob/main/Visualizacao_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Visualização de dados incorparada ao pandas
# O pandas tem metodos que geram gráficos diretamento do dataframe

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df1 = pd.read_csv("/content/df1", index_col=0)
df1
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
df2 = pd.read_csv("/content/df2")
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %% [markdown]
# ## Folha de estilo
# Aplica um estilo que melhora a aparência padrão dos graficos.
# >Matplotlib tem [folhas de estilo](http://matplotlib.org/gallery.html#style_sheets) que você pode usar para tornar seus plots mais agradáveis. Essas folhas de estilo incluem plot_bmh, plot_fivethirtyeight, plot_ggplot e muito mais. Eles basicamente criam um conjunto de regras de estilo que seus plots seguirão. Eu recomendo usá-los dado que eles farão seus plots terem uma aparência muito mais profissional. Você pode até mesmo criar o seu próprio caso você deseja que os gráficos de sua empresa tenham todos o mesmo aspecto (é um pouco tedioso para criar).

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
# histograma de uma coluna específica
df1["A"].hist()

# %%
df1["A"].hist(bins=30)

# %% [markdown]
# # Tipos de graficos
# Tipos de plotagem
# Existem vários tipos de plots incorporados aos pandas, a maioria deles plots estatísticos por natureza:
#
# - df.plot.area
# - df.plot.barh
# - df.plot.density
# - df.plot.hist
# - df.plot.line
# - df.plot.scatter
# - df.plot.bar
# - df.plot.box
# - df.plot.hexbin
# - df.plot.kde
# - df.plot.pie
#
# >Você também pode simplesmente chamar df.plot (kind = 'hist') ou substituir esse argumento por qualquer um dos termos-chave mostrados na lista acima (por exemplo, 'caixa', 'barh', etc.)

# %% [markdown]
# ### Área

# %%
# todos os parametros de configuração do matplotlib podem ser usados nestes graficos como o alpha
df2[["a", "b"]].plot.area(alpha=0.4)

# %% [markdown]
# ### Bar

# %%
df1["year"] = pd.to_datetime(df1.index).year

df1
# Out:
#                    A         B         C         D  year
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233  2000
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382  2000
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638  2000
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085  2000
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436  2000
# ...              ...       ...       ...       ...   ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537  2002
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483  2002
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605  2002
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844  2002
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427  2002
#
# [1000 rows x 5 columns]

# %%
df1["year"].value_counts().plot.bar()

# %% [markdown]
# ### Scatter

# %%
# c = variação de cor
# s = variaçao de tamanho
df1.plot.scatter(x="A", y="B", c="B")

# %%
df1.plot.scatter(x="A", y="B", s=df1["B"]*30)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/collections.py:885: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# ### Boxplot

# %%
df2[["a", "b", "c"]].plot.box()

# %% [markdown]
# ### Hexbin

# %%
dados = pd.DataFrame(np.random.randn(1000, 2), columns=["A", "B"])
dados.plot.hexbin(x="A", y="B", gridsize=20)
