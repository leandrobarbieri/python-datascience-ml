# %% [markdown]
# <a href="https://colab.research.google.com/github/leandrobarbieri/python-datascience-ml/blob/main/Matplotlib_pyplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib.pyplot
# Biblioteca padrão para visualização de dados, usada pelas outras como base para os gráficos.
# https://matplotlib.org/stable/gallery/index.html

# %%
import numpy as np
import matplotlib.pyplot as plt

# tamanho padrão da fig caso não seja especificado
plt.rc('figure', figsize=(10, 3))

# visualizar os graficos criados na propria linha de codigo usada para definição
# não precisar escrever plt.show()
# %matplotlib inline

# %% [markdown]
# # Sem criar figures
# Criando diretamente usando o modulo importado plt sem criar figure e axes

# %%
# dados de testes para usar nos eixos dos graficos
x = np.linspace(0, 5, 11)
y = x * x

# %%
# passando dados no eixo x e y e a cor da linha (plot padrão é linha)
plt.plot(x, y, color="red")

# rótulos dos eixos e título
plt.xlabel("Eixo X")
plt.ylabel("Eixo Y")
plt.title("Titulo")
# Out:
# Text(0.5, 1.0, 'Titulo')

# %%
# alterando o tipo de plot (linha) para scatter/bar/step/fill_between
plt.scatter(x, y, color="red")
plt.xlabel("Eixo X")
plt.ylabel("Eixo Y")
plt.title("Titulo")
# Out:
# Text(0.5, 1.0, 'Titulo')

# %% [markdown]
# ## Subplots sem criar figures
# Usando um mesmo plt podemos ter várias subplots apenas chamando .subplot e passando a quantidade e a posiação na matriz de plots

# %%
# Figure com uma linha e 3 colunas
plt.figure(figsize=(12,3))

# subplots: 1
plt.subplot(1, 3, 1)
plt.plot(x, y, color="red")

# subplots: 2
plt.subplot(1, 3, 2, )
plt.scatter(y, x, color="blue")


# subplots: 3
plt.subplot(1, 3, 3)
plt.bar(y, x, color="blue")
# Out:
# <BarContainer object of 11 artists>

# %% [markdown]
# # Utilizando figure
# Criando um objeto figure e adicionando axes (plots)

# %% [markdown]
# ## adicionando axes

# %%
# fig caixa vazia para ter controle total sobre a figura e subplots
fig = plt.figure(figsize=(15,3))

# add_axes cria subplots e adiciona na figura nas posições (em percentual das extremidade)
axes1 = fig.add_axes([0.1, 0.1, 0.5, 1])
axes2 = fig.add_axes([0.7, 0.1, 0.5, 1])

# setando propriedades do axes1
axes1.set_xlabel("Eixo-X1")
axes1.set_ylabel("Eixo-Y1")
axes1.set_title("Titulo1")
axes1.plot(x, y)

# setando propriedades do axes2
axes2.set_xlabel("Eixo-X2")
axes2.set_ylabel("Eixo-Y2")
axes2.set_title("Titulo2")
axes2.set_label("legenda")
axes2.bar(x, y)
# Out:
# No handles with labels found to put in legend.
# <BarContainer object of 11 artists>

# %% [markdown]
# # Criando subplots
# Método plt.subplots() util de para criar uma matriz de subplots

# %%
# criando um único subplots
fig, ax = plt.subplots(figsize=(12,3))

# mais de uma linha em um mesmo subplot
ax.plot(x, x**3, "b--")
ax.plot(x, x**4, "g--")

ax.set_xlabel("EixoX")
ax.set_ylabel("EixoY")
ax.set_title("Titulo")
# Out:
# Text(0.5, 1.0, 'Titulo')

# %%
# criando vários subplots 
# retorna uma matriz de objetos subplots
fig, ax = plt.subplots(nrows=2, ncols=3)

# acessando a primeira
ax[0, 0].plot(x, y*y, "r--") 
ax[0][0].set_xlabel("Label1 ax[0][0]")

ax[0][1].plot(x, y*y, "r--") 
ax[0][1].set_xlabel("Label1 ax[0][1]")

ax[0][2].plot(x, y*y, "r--") 
ax[0][2].set_xlabel("Label1 ax[0][2]")

# acessando a segunda
ax[1][0].plot(x, y*2, "b--") 
ax[1][0].set_xlabel("Label2 ax[1][0]")

ax[1][1].plot(x, y*2, "b--") 
ax[1][1].set_xlabel("Label2 ax[1][1]")

ax[1][2].plot(x, y*2, "b--") 
ax[1][2].set_xlabel("Label2 ax[1][2]")

# Ajusta os subplots para evitar sobreposições e melhorar a apresentaçao
plt.tight_layout()

# %%
# Ajustando o tamanho e a resolução
fig = plt.figure(figsize=(8,4), dpi=100)

# %%
# Grafico com legenda
fig, axes = plt.subplots(figsize=(12,2))
axes.plot(x, x, "r--", label="Red (x - x)")
axes.plot(y, x, "g--", label="Green (x - y)")
axes.set_title("Titulo1")

# loc=0 o matplotlib escolhe o melhor lugar
axes.legend(loc=0)

# %% [markdown]
# ## Salvando o grafico como imagem

# %%
# salva a imagem como o nome e o formato escolhido no diretorio do jupyter
fig.savefig("imagem.jpg")

# %%
# cria uma matriz de subplots com 1 linhas e 2 colunas
# ajusta o tamanho da figura para 16,3
# sharey=True mantém o mesmo rotulo de eixo y para todos os graficos na mesma linha da matriz de subplots
fig, axes = plt.subplots(ncols=2, nrows=1, figsize=(16,3), sharey=True)

# subplot 1: marcadores e linha fina
axes[0].plot(x, y, color="red",  linewidth=0.5, linestyle=":", marker="+", markersize=5, markerfacecolor="yellow")
axes[0].set_xlim([0, 10])
axes[0].set_ylim([0, 30])
axes[0].set_title("Titulo1")
axes[0].set_ylabel("Eixo compartilhado")

# cores com nome e formato hex, linha grossa, transparencia, marcador, grids
axes[1].set_title("Titulo2")
axes[1].plot(x, y, color="#8B8B8B", linewidth=10, alpha=0.1, linestyle="--", marker="o", markersize=16, markerfacecolor="red")
axes[1].grid(color='#8B8B8B', alpha=0.5, linestyle='dashed', linewidth=0.5)

# %% [markdown]
# ## Dois eixos
# Gráfico com dois eixos

# %%
fig, ax1 = plt.subplots()

ax1.plot(x, x**2, lw=2, color="blue")
ax1.set_ylabel(r"area $(m^2)$", fontsize=18, color="blue")

# itera sob os rotuos do eixo y
for label in ax1.get_yticklabels():
    label.set_color("blue")
    
# cria o eixo secundario, compartilhando o mesmo eixo x 
ax2 = ax1.twinx()
ax2.plot(x, x**3, lw=2, color="red")
ax2.set_ylabel(r"volume $(m^3)$", fontsize=18, color="red")

# itera sob os rotuos do eixo y
for label in ax2.get_yticklabels():
    label.set_color("red")

# %% [markdown]
# # Outros tipos graficos

# %%
# dados de testes
n = np.array([0,1,2,3,4,5])

# uma linha e 4 colunas de subplots
fig, axes = plt.subplots(1, 4, figsize=(12,3))

# scatter
axes[0].scatter(x, x + 0.25*np.random.randn(len(x)))
axes[0].set_title("scatter")

# grafico tipo step
axes[1].step(n, n**2, lw=2, color="green", linestyle=":")
axes[1].set_title("step")

# grafico tipo barra
axes[2].bar(n, n**2, align="center", width=0.9, alpha=0.3)
axes[2].set_title("bar")

# fill
axes[3].fill_between(x, x**2, x**3, color="green", alpha=0.5);
axes[3].set_title("fill_between");

# %% [markdown]
# ## Anotações no grafico

# %%
# inserir texto dentro dos graficos
fig, ax = plt.subplots(figsize=(12,2))

ax.plot(x, x**2, x, x**3)

# controla a posição do texto
ax.text(5, 20, r"$y=x^2$", fontsize=20, color="blue")
ax.text(5, 100, r"$y=x^3$", fontsize=20, color="orange");

# %% [markdown]
# # Estrutura de subplots complexos (dashboard)

# %%
fig = plt.figure()
ax1 = plt.subplot2grid((3,3), (0,0), colspan=3)
ax2 = plt.subplot2grid((3,3), (1,0), colspan=2)
ax3 = plt.subplot2grid((3,3), (1,2), rowspan=2)
ax4 = plt.subplot2grid((3,3), (2,0))
ax5 = plt.subplot2grid((3,3), (2,1))
fig.tight_layout()
